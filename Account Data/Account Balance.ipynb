# %%
from ib_insync import *

util.startLoop()

ib = IB()
ib.connect()
# Out:
# <IB connected to 127.0.0.1:7497 clientId=1>

# %%
# See Values
try:
    values = ib.accountValues()
except Exception as e:
    print(e)
    
values
# Out:
# [AccountValue(account='DU229676', tag='AccountCode', value='DU229676', currency='', modelCode=''),
#  AccountValue(account='DU229676', tag='AccountOrGroup', value='DU229676', currency='BASE', modelCode=''),
#  AccountValue(account='DU229676', tag='AccountOrGroup', value='DU229676', currency='USD', modelCode=''),
#  AccountValue(account='DU229676', tag='AccountReady', value='true', currency='', modelCode=''),
#  AccountValue(account='DU229676', tag='AccountType', value='LLC', currency='', modelCode=''),
#  AccountValue(account='DU229676', tag='AccruedCash', value='0.00', currency='BASE', modelCode=''),
#  AccountValue(account='DU229676', tag='AccruedCash', value='0.00', currency='USD', modelCode=''),
#  AccountValue(account='DU229676', tag='AccruedCash-C', value='0.00', currency='USD', modelCode=''),
#  AccountValue(account='DU229676', tag='AccruedCash-S', value='0.00', currency='USD', modelCode=''),
# ...

# %%
for value in values:
    if value.tag == 'AvailableFunds':
        print(value)
# Out:
# AccountValue(account='DU229676', tag='AvailableFunds', value='1037875.11', currency='USD', modelCode='')
